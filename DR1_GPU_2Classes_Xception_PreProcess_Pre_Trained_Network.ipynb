# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/FatmaSayedAhmed/PhDResearch/blob/master/DR1_GPU_2Classes_Xception_PreProcess_Pre_Trained_Network.ipynb)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ### Class 0 Vs Class 1

# %%
import tensorflow as tf 
import keras
import os

from subprocess import check_output

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from PIL import Image

from keras.applications.xception import preprocess_input

from keras.preprocessing import image

from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

from sklearn.cross_validation import train_test_split

from keras.utils import np_utils

from keras.applications.xception import Xception

from keras.models import Model, load_model

from keras.layers import Dense, Dropout, Reshape

from keras.optimizers import SGD

import matplotlib.pyplot as plt

from sklearn.metrics import classification_report,confusion_matrix

from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten 
from keras import backend as K
from keras import applications


os.environ["CUDA_VISIBLE_DEVICES"] = '0' #use GPU with ID=0
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7 # maximun alloc gpu50% of MEM
sess = tf.Session(config = config)
keras.backend.set_session(sess)


# dimensions of our images.
img_width, img_height = 224, 224

top_model_weights_path = '/content/gdrive/My Drive/Colab Notebooks/bottleneck_fc_model_Xception_PP_PTN_data1.h5'

train_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data1_Train1708_Test732/train'
validation_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data1_Train1708_Test732/validation'
nb_train_samples = 3416
nb_validation_samples = 1464

epochs = 50
batch_size = 8  # batch size in flow_images_from_directory needs to correspond to the image number of the test images.


def save_bottleneck_features():
    datagen = ImageDataGenerator(rescale=1. / 255)

    # build the Xception network
    model = Xception(weights='imagenet', include_top=False)
    
    #model.summary()
    
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    
    bottleneck_features_train = model.predict_generator(
        generator, nb_train_samples // batch_size)
    np.save(open('DR1_bottleneck_features_train_Xception_PP_PTN_data1.npy', 'wb'),
            bottleneck_features_train)

    generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_validation = model.predict_generator(
        generator, nb_validation_samples // batch_size)
    np.save(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data1.npy', 'wb'),
            bottleneck_features_validation)


def train_top_model():
    train_data = np.load(open('DR1_bottleneck_features_train_Xception_PP_PTN_data1.npy','rb'))
    train_labels = np.array(
        [0] * (nb_train_samples // 2) + [1] * (nb_train_samples // 2))

    preprocess_input(train_data)   

    print(' train_labels shape',train_labels.shape)

    #print(' train_labels : \n ',train_labels)

    validation_data = np.load(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data1.npy','rb'))
    validation_labels = np.array(
        [0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))

    preprocess_input(validation_data)   

    print(' validation_labels shape',validation_labels.shape)

    #print(' validation_labels : \n ',validation_labels)

    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy', metrics=['accuracy'])

    model.fit(train_data, train_labels,
              epochs=epochs,
              batch_size=batch_size,
              validation_data=(validation_data, validation_labels))
    model.save_weights(top_model_weights_path)
    
    print('-------------------------------------------------------------------')
    print('------------------ Evalute the train set ------------------------')
    print('-------------------------------------------------------------------')

    train_score = model.evaluate(train_data, train_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('Train loss:', train_score[0])
    print('Train accuracy:', train_score[1])

    y_pred_train = np.squeeze(model.predict(train_data))
    print(' y_pred_train shape',y_pred_train.shape)
    #print(' y_pred_train : \n ',y_pred_train)

    threshold = 0.5
    y_pred_train = (y_pred_train > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_train again: \n ',y_pred_train)
    
    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=True)
    print('accuracy_score_train with normalize=True: ', accuracy_score_train)

    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=False)
    print('accuracy_score_train with normalize=False : ', accuracy_score_train)

    target_names = ['class 0', 'class 1']

    print(classification_report(y_pred_train, train_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_train, train_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )

    print('-------------------------------------------------------------------')
    print('------------------ Evalute the validation set ------------------------')
    print('-------------------------------------------------------------------')

    validation_score = model.evaluate(validation_data, validation_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('validation loss:', validation_score[0])
    print('validation accuracy:', validation_score[1])

    y_pred_validation = np.squeeze(model.predict(validation_data))
    print(' y_pred_train shape',y_pred_validation.shape)
    #print(' y_pred_train : \n ',y_pred_validation)

    y_pred_validation = (y_pred_validation > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_validation again: \n ',y_pred_validation)
    
    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=True)
    print('accuracy_score_validation with normalize=True: ', accuracy_score_validation)

    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=False)
    print('accuracy_score_validation with normalize=False : ', accuracy_score_validation)

    print(classification_report(y_pred_validation, validation_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_validation, validation_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )


save_bottleneck_features()
train_top_model()

print('-------------------------------------------------------------------')
print('------------------ Train Done -------------------------------------')
print('-------------------------------------------------------------------')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Found 3416 images belonging to 2 classes.
# Found 1464 images belonging to 2 classes.
#  train_labels shape (3416,)
#  validation_labels shape (1464,)
# Train on 3416 samples, validate on 1464 samples
# Epoch 1/50
# 3416/3416 [==============================] - 15s 5ms/step - loss: 8.0417 - acc: 0.5006 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 2/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 3/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 4/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 5/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 6/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 7/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 8/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 9/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 10/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 11/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 12/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 13/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 14/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 15/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 16/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 17/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 18/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 19/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 20/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 21/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 22/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 23/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 24/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 25/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 26/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 27/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 28/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 29/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 30/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 31/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 32/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 33/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 34/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 35/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 36/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 37/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 38/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 39/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 40/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 41/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 42/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 43/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 44/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 45/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 46/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 47/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 48/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 49/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 50/50
# 3416/3416 [==============================] - 14s 4ms/step - loss: 8.0590 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# -------------------------------------------------------------------
# ------------------ Evalute the train set ------------------------
# -------------------------------------------------------------------
# Train loss: 8.059047748623328
# Train accuracy: 0.5
#  y_pred_train shape (3416,)
# accuracy_score_train with normalize=True:  0.5
# accuracy_score_train with normalize=False :  1708
#              precision    recall  f1-score   support
#
#     class 0       1.00      0.50      0.67      3416
#     class 1       0.00      0.00      0.00         0
#
# avg / total       1.00      0.50      0.67      3416
#
# confusion_matrix :
#  [[1708 1708]
#  [   0    0]]
# Accuracy :  0.5
# Sensitivity :  1.0
# Specificity :  0.0
# -------------------------------------------------------------------
# ------------------ Evalute the validation set ------------------------
# -------------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# validation loss: 8.059047747062047
# validation accuracy: 0.5
#  y_pred_train shape (1464,)
# accuracy_score_validation with normalize=True:  0.5
# accuracy_score_validation with normalize=False :  732
#              precision    recall  f1-score   support
#
#     class 0       1.00      0.50      0.67      1464
#     class 1       0.00      0.00      0.00         0
#
# avg / total       1.00      0.50      0.67      1464
#
# confusion_matrix :
#  [[732 732]
#  [  0   0]]
# Accuracy :  0.5
# Sensitivity :  1.0
# Specificity :  0.0
# -------------------------------------------------------------------
# ------------------ Train Done -------------------------------------
# -------------------------------------------------------------------

# %% [markdown]
# ### Class 0 Vs Class 2

# %%
import tensorflow as tf 
import keras
import os

from subprocess import check_output

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from PIL import Image

from keras.applications.xception import preprocess_input

from keras.preprocessing import image

from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

from sklearn.cross_validation import train_test_split

from keras.utils import np_utils

from keras.applications.xception import Xception

from keras.models import Model, load_model

from keras.layers import Dense, Dropout, Reshape

from keras.optimizers import SGD

import matplotlib.pyplot as plt

from sklearn.metrics import classification_report,confusion_matrix

from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten 
from keras import backend as K
from keras import applications


os.environ["CUDA_VISIBLE_DEVICES"] = '0' #use GPU with ID=0
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7 # maximun alloc gpu50% of MEM
sess = tf.Session(config = config)
keras.backend.set_session(sess)


# dimensions of our images.
img_width, img_height = 224, 224

top_model_weights_path = '/content/gdrive/My Drive/Colab Notebooks/bottleneck_fc_model_Xception_PP_PTN_data2.h5'

train_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data2_Train3704_Test1588/train'
validation_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data2_Train3704_Test1588/validation'
nb_train_samples = 7408
nb_validation_samples = 3176

epochs = 50
batch_size = 8  # batch size in flow_images_from_directory needs to correspond to the image number of the test images.


def save_bottleneck_features():
    datagen = ImageDataGenerator(rescale=1. / 255)

    # build the Xception network
    model = Xception(weights='imagenet', include_top=False)
    
    #model.summary()
    
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    
    bottleneck_features_train = model.predict_generator(
        generator, nb_train_samples // batch_size)
    np.save(open('DR1_bottleneck_features_train_Xception_PP_PTN_data2.npy', 'wb'),
            bottleneck_features_train)

    generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_validation = model.predict_generator(
        generator, nb_validation_samples // batch_size)
    np.save(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data2.npy', 'wb'),
            bottleneck_features_validation)


def train_top_model():
    train_data = np.load(open('DR1_bottleneck_features_train_Xception_PP_PTN_data2.npy','rb'))
    train_labels = np.array(
        [0] * (nb_train_samples // 2) + [1] * (nb_train_samples // 2))

    preprocess_input(train_data)   

    print(' train_labels shape',train_labels.shape)

    #print(' train_labels : \n ',train_labels)

    validation_data = np.load(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data2.npy','rb'))
    validation_labels = np.array(
        [0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))

    preprocess_input(validation_data)   

    print(' validation_labels shape',validation_labels.shape)

    #print(' validation_labels : \n ',validation_labels)

    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy', metrics=['accuracy'])

    model.fit(train_data, train_labels,
              epochs=epochs,
              batch_size=batch_size,
              validation_data=(validation_data, validation_labels))
    model.save_weights(top_model_weights_path)
    
    print('-------------------------------------------------------------------')
    print('------------------ Evalute the train set ------------------------')
    print('-------------------------------------------------------------------')

    train_score = model.evaluate(train_data, train_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('Train loss:', train_score[0])
    print('Train accuracy:', train_score[1])

    y_pred_train = np.squeeze(model.predict(train_data))
    print(' y_pred_train shape',y_pred_train.shape)
    #print(' y_pred_train : \n ',y_pred_train)

    threshold = 0.5
    y_pred_train = (y_pred_train > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_train again: \n ',y_pred_train)
    
    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=True)
    print('accuracy_score_train with normalize=True: ', accuracy_score_train)

    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=False)
    print('accuracy_score_train with normalize=False : ', accuracy_score_train)

    target_names = ['class 0', 'class 1']

    print(classification_report(y_pred_train, train_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_train, train_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )

    print('-------------------------------------------------------------------')
    print('------------------ Evalute the validation set ------------------------')
    print('-------------------------------------------------------------------')

    validation_score = model.evaluate(validation_data, validation_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('validation loss:', validation_score[0])
    print('validation accuracy:', validation_score[1])

    y_pred_validation = np.squeeze(model.predict(validation_data))
    print(' y_pred_train shape',y_pred_validation.shape)
    #print(' y_pred_train : \n ',y_pred_validation)

    y_pred_validation = (y_pred_validation > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_validation again: \n ',y_pred_validation)
    
    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=True)
    print('accuracy_score_validation with normalize=True: ', accuracy_score_validation)

    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=False)
    print('accuracy_score_validation with normalize=False : ', accuracy_score_validation)

    print(classification_report(y_pred_validation, validation_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_validation, validation_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )


save_bottleneck_features()
train_top_model()

print('-------------------------------------------------------------------')
print('------------------ Train Done -------------------------------------')
print('-------------------------------------------------------------------')
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Found 7408 images belonging to 2 classes.
# Found 3176 images belonging to 2 classes.
#  train_labels shape (7408,)
#  validation_labels shape (3176,)
# Train on 7408 samples, validate on 3176 samples
# Epoch 1/50
# 7408/7408 [==============================] - 35s 5ms/step - loss: 7.9635 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 2/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 3/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 4/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 5/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 6/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 7/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 8/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 9/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 10/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 11/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 12/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 13/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 14/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 15/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 16/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 17/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 18/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 19/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 20/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 21/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 22/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 23/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 24/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 25/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 26/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 27/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 28/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 29/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 30/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 31/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 32/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 33/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 34/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 35/50
# 7408/7408 [==============================] - 35s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 36/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 37/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 38/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 39/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 40/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 41/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 42/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 43/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 44/50
# 7408/7408 [==============================] - 33s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 45/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 46/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 47/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 48/50
# 7408/7408 [==============================] - 34s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 49/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 50/50
# 7408/7408 [==============================] - 33s 5ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# -------------------------------------------------------------------
# ------------------ Evalute the train set ------------------------
# -------------------------------------------------------------------
# Train loss: 7.971192421459997
# Train accuracy: 0.5
#  y_pred_train shape (7408,)
# accuracy_score_train with normalize=True:  0.5
# accuracy_score_train with normalize=False :  3704
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00         0
#     class 1       1.00      0.50      0.67      7408
#
# avg / total       1.00      0.50      0.67      7408
#
# confusion_matrix :
#  [[   0    0]
#  [3704 3704]]
# Accuracy :  0.5
# Sensitivity :  0.0
# Specificity :  1.0
# -------------------------------------------------------------------
# ------------------ Evalute the validation set ------------------------
# -------------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# validation loss: 7.971192416676346
# validation accuracy: 0.5
#  y_pred_train shape (3176,)
# accuracy_score_validation with normalize=True:  0.5
# accuracy_score_validation with normalize=False :  1588
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00         0
#     class 1       1.00      0.50      0.67      3176
#
# avg / total       1.00      0.50      0.67      3176
#
# confusion_matrix :
#  [[   0    0]
#  [1588 1588]]
# Accuracy :  0.5
# Sensitivity :  0.0
# Specificity :  1.0
# -------------------------------------------------------------------
# ------------------ Train Done -------------------------------------
# -------------------------------------------------------------------

# %% [markdown]
# ### Class 0 Vs Class 3

# %%
import tensorflow as tf 
import keras
import os

from subprocess import check_output

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from PIL import Image

from keras.applications.xception import preprocess_input

from keras.preprocessing import image

from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

from sklearn.cross_validation import train_test_split

from keras.utils import np_utils

from keras.applications.xception import Xception

from keras.models import Model, load_model

from keras.layers import Dense, Dropout, Reshape

from keras.optimizers import SGD

import matplotlib.pyplot as plt

from sklearn.metrics import classification_report,confusion_matrix

from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten 
from keras import backend as K
from keras import applications


os.environ["CUDA_VISIBLE_DEVICES"] = '0' #use GPU with ID=0
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7 # maximun alloc gpu50% of MEM
sess = tf.Session(config = config)
keras.backend.set_session(sess)


# dimensions of our images.
img_width, img_height = 224, 224

top_model_weights_path = '/content/gdrive/My Drive/Colab Notebooks/bottleneck_fc_model_Xception_PP_PTN_data3.h5'

train_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data3_Train608_Test260/train'
validation_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data3_Train608_Test260/validation'
nb_train_samples = 1216
nb_validation_samples = 520

epochs = 50
batch_size = 8  # batch size in flow_images_from_directory needs to correspond to the image number of the test images.


def save_bottleneck_features():
    datagen = ImageDataGenerator(rescale=1. / 255)

    # build the Xception network
    model = Xception(weights='imagenet', include_top=False)
    
    #model.summary()
    
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    
    bottleneck_features_train = model.predict_generator(
        generator, nb_train_samples // batch_size)
    np.save(open('DR1_bottleneck_features_train_Xception_PP_PTN_data3.npy', 'wb'),
            bottleneck_features_train)

    generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_validation = model.predict_generator(
        generator, nb_validation_samples // batch_size)
    np.save(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data3.npy', 'wb'),
            bottleneck_features_validation)


def train_top_model():
    train_data = np.load(open('DR1_bottleneck_features_train_Xception_PP_PTN_data3.npy','rb'))
    train_labels = np.array(
        [0] * (nb_train_samples // 2) + [1] * (nb_train_samples // 2))

    preprocess_input(train_data)   

    print(' train_labels shape',train_labels.shape)

    #print(' train_labels : \n ',train_labels)

    validation_data = np.load(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data3.npy','rb'))
    validation_labels = np.array(
        [0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))

    preprocess_input(validation_data)   

    print(' validation_labels shape',validation_labels.shape)

    #print(' validation_labels : \n ',validation_labels)

    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy', metrics=['accuracy'])

    model.fit(train_data, train_labels,
              epochs=epochs,
              batch_size=batch_size,
              validation_data=(validation_data, validation_labels))
    model.save_weights(top_model_weights_path)
    
    print('-------------------------------------------------------------------')
    print('------------------ Evalute the train set ------------------------')
    print('-------------------------------------------------------------------')

    train_score = model.evaluate(train_data, train_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('Train loss:', train_score[0])
    print('Train accuracy:', train_score[1])

    y_pred_train = np.squeeze(model.predict(train_data))
    print(' y_pred_train shape',y_pred_train.shape)
    #print(' y_pred_train : \n ',y_pred_train)

    threshold = 0.5
    y_pred_train = (y_pred_train > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_train again: \n ',y_pred_train)
    
    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=True)
    print('accuracy_score_train with normalize=True: ', accuracy_score_train)

    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=False)
    print('accuracy_score_train with normalize=False : ', accuracy_score_train)

    target_names = ['class 0', 'class 1']

    print(classification_report(y_pred_train, train_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_train, train_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )

    print('-------------------------------------------------------------------')
    print('------------------ Evalute the validation set ------------------------')
    print('-------------------------------------------------------------------')

    validation_score = model.evaluate(validation_data, validation_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('validation loss:', validation_score[0])
    print('validation accuracy:', validation_score[1])

    y_pred_validation = np.squeeze(model.predict(validation_data))
    print(' y_pred_train shape',y_pred_validation.shape)
    #print(' y_pred_train : \n ',y_pred_validation)

    y_pred_validation = (y_pred_validation > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_validation again: \n ',y_pred_validation)
    
    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=True)
    print('accuracy_score_validation with normalize=True: ', accuracy_score_validation)

    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=False)
    print('accuracy_score_validation with normalize=False : ', accuracy_score_validation)

    print(classification_report(y_pred_validation, validation_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_validation, validation_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )


save_bottleneck_features()
train_top_model()

print('-------------------------------------------------------------------')
print('------------------ Train Done -------------------------------------')
print('-------------------------------------------------------------------')
# Out:
# Found 1216 images belonging to 2 classes.
# Found 520 images belonging to 2 classes.
#  train_labels shape (1216,)
#  validation_labels shape (520,)
# Train on 1216 samples, validate on 520 samples
# Epoch 1/50
# 1216/1216 [==============================] - 7s 6ms/step - loss: 7.9522 - acc: 0.4967 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 2/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 3/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 4/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 5/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 6/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 7/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 8/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 9/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 10/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 11/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 12/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 13/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 14/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 15/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 16/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 17/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 18/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 19/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 20/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 21/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 22/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 23/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 24/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 25/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 26/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 27/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 28/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 29/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 30/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 31/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 32/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 33/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 34/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 35/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 36/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 37/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 38/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 39/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 40/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 41/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 42/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 43/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 44/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 45/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 46/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 47/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 48/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 49/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 50/50
# 1216/1216 [==============================] - 5s 4ms/step - loss: 7.9712 - acc: 0.5000 - val_loss: 7.9712 - val_acc: 0.5000
# -------------------------------------------------------------------
# ------------------ Evalute the train set ------------------------
# -------------------------------------------------------------------
# Train loss: 7.97119241952899
# Train accuracy: 0.5
#  y_pred_train shape (1216,)
# accuracy_score_train with normalize=True:  0.5
# accuracy_score_train with normalize=False :  608
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00         0
#     class 1       1.00      0.50      0.67      1216
#
# avg / total       1.00      0.50      0.67      1216
#
# confusion_matrix :
#  [[  0   0]
#  [608 608]]
# Accuracy :  0.5
# Sensitivity :  0.0
# Specificity :  1.0
# -------------------------------------------------------------------
# ------------------ Evalute the validation set ------------------------
# -------------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# validation loss: 7.9711924204459805
# validation accuracy: 0.5
#  y_pred_train shape (520,)
# accuracy_score_validation with normalize=True:  0.5
# accuracy_score_validation with normalize=False :  260
#              precision    recall  f1-score   support
#
#     class 0       0.00      0.00      0.00         0
#     class 1       1.00      0.50      0.67       520
#
# avg / total       1.00      0.50      0.67       520
#
# confusion_matrix :
#  [[  0   0]
#  [260 260]]
# Accuracy :  0.5
# Sensitivity :  0.0
# Specificity :  1.0
# -------------------------------------------------------------------
# ------------------ Train Done -------------------------------------
# -------------------------------------------------------------------

# %% [markdown]
# ### Class 0 Vs Class 4

# %%
import tensorflow as tf 
import keras
import os

from subprocess import check_output

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from PIL import Image

from keras.applications.xception import preprocess_input

from keras.preprocessing import image

from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

from sklearn.cross_validation import train_test_split

from keras.utils import np_utils

from keras.applications.xception import Xception

from keras.models import Model, load_model

from keras.layers import Dense, Dropout, Reshape

from keras.optimizers import SGD

import matplotlib.pyplot as plt

from sklearn.metrics import classification_report,confusion_matrix

from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten 
from keras import backend as K
from keras import applications


os.environ["CUDA_VISIBLE_DEVICES"] = '0' #use GPU with ID=0
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7 # maximun alloc gpu50% of MEM
sess = tf.Session(config = config)
keras.backend.set_session(sess)


# dimensions of our images.
img_width, img_height = 224, 224

top_model_weights_path = '/content/gdrive/My Drive/Colab Notebooks/bottleneck_fc_model_Xception_PP_PTN_data4.h5'

train_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data4_Train496_Test212/train'
validation_data_dir = '/content/gdrive/My Drive/Colab Notebooks/data4_Train496_Test212/validation'
nb_train_samples = 992
nb_validation_samples = 424

epochs = 50
batch_size = 8  # batch size in flow_images_from_directory needs to correspond to the image number of the test images.


def save_bottleneck_features():
    datagen = ImageDataGenerator(rescale=1. / 255)

    # build the Xception network
    model = Xception(weights='imagenet', include_top=False)
    
    #model.summary()
    
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    
    bottleneck_features_train = model.predict_generator(
        generator, nb_train_samples // batch_size)
    np.save(open('DR1_bottleneck_features_train_Xception_PP_PTN_data4.npy', 'wb'),
            bottleneck_features_train)

    generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    bottleneck_features_validation = model.predict_generator(
        generator, nb_validation_samples // batch_size)
    np.save(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data4.npy', 'wb'),
            bottleneck_features_validation)


def train_top_model():
    train_data = np.load(open('DR1_bottleneck_features_train_Xception_PP_PTN_data4.npy','rb'))
    train_labels = np.array(
        [0] * (nb_train_samples // 2) + [1] * (nb_train_samples // 2))

    preprocess_input(train_data)   

    print(' train_labels shape',train_labels.shape)

    #print(' train_labels : \n ',train_labels)

    validation_data = np.load(open('DR1_bottleneck_features_validation_Xception_PP_PTN_data4.npy','rb'))
    validation_labels = np.array(
        [0] * (nb_validation_samples // 2) + [1] * (nb_validation_samples // 2))

    preprocess_input(validation_data)   

    print(' validation_labels shape',validation_labels.shape)

    #print(' validation_labels : \n ',validation_labels)

    model = Sequential()
    model.add(Flatten(input_shape=train_data.shape[1:]))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy', metrics=['accuracy'])

    model.fit(train_data, train_labels,
              epochs=epochs,
              batch_size=batch_size,
              validation_data=(validation_data, validation_labels))
    model.save_weights(top_model_weights_path)
    
    print('-------------------------------------------------------------------')
    print('------------------ Evalute the train set ------------------------')
    print('-------------------------------------------------------------------')

    train_score = model.evaluate(train_data, train_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('Train loss:', train_score[0])
    print('Train accuracy:', train_score[1])

    y_pred_train = np.squeeze(model.predict(train_data))
    print(' y_pred_train shape',y_pred_train.shape)
    #print(' y_pred_train : \n ',y_pred_train)

    threshold = 0.5
    y_pred_train = (y_pred_train > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_train again: \n ',y_pred_train)
    
    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=True)
    print('accuracy_score_train with normalize=True: ', accuracy_score_train)

    accuracy_score_train = accuracy_score(train_labels, y_pred_train, normalize=False)
    print('accuracy_score_train with normalize=False : ', accuracy_score_train)

    target_names = ['class 0', 'class 1']

    print(classification_report(y_pred_train, train_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_train, train_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )

    print('-------------------------------------------------------------------')
    print('------------------ Evalute the validation set ------------------------')
    print('-------------------------------------------------------------------')

    validation_score = model.evaluate(validation_data, validation_labels, verbose=0) # nb_train_samples // batch_size, workers=1)
    print('validation loss:', validation_score[0])
    print('validation accuracy:', validation_score[1])

    y_pred_validation = np.squeeze(model.predict(validation_data))
    print(' y_pred_train shape',y_pred_validation.shape)
    #print(' y_pred_train : \n ',y_pred_validation)

    y_pred_validation = (y_pred_validation > threshold)*1
    #y_pred_train.astype(int)   
    #print(' y_pred_validation again: \n ',y_pred_validation)
    
    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=True)
    print('accuracy_score_validation with normalize=True: ', accuracy_score_validation)

    accuracy_score_validation = accuracy_score(validation_labels, y_pred_validation, normalize=False)
    print('accuracy_score_validation with normalize=False : ', accuracy_score_validation)

    print(classification_report(y_pred_validation, validation_labels, target_names=target_names))

    cm1 = confusion_matrix(y_pred_validation, validation_labels)
    
    print('confusion_matrix : \n', cm1)

    total1=sum(sum(cm1))

    #####from confusion matrix calculate accuracy
    accuracy1=(cm1[0,0]+cm1[1,1])/total1
    print ('Accuracy : ', accuracy1)

    sensitivity = cm1[0,0]/(cm1[0,0]+cm1[1,0])
    print('Sensitivity : ', sensitivity )

    Specificity = cm1[1,1]/(cm1[1,1]+cm1[0,1])
    print('Specificity : ', Specificity )


save_bottleneck_features()
train_top_model()

print('-------------------------------------------------------------------')
print('------------------ Train Done -------------------------------------')
print('-------------------------------------------------------------------')
# Out:
# Found 996 images belonging to 2 classes.
# Found 424 images belonging to 2 classes.
#  train_labels shape (992,)
#  validation_labels shape (424,)
# Train on 992 samples, validate on 424 samples
# Epoch 1/50
# 992/992 [==============================] - 6s 6ms/step - loss: 7.8725 - acc: 0.4990 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 2/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.8308 - acc: 0.5081 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 3/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.7602 - acc: 0.5111 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 4/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.7812 - acc: 0.5101 - val_loss: 7.9712 - val_acc: 0.5000
# Epoch 5/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9412 - acc: 0.5020 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 6/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9846 - acc: 0.5020 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 7/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.7134 - acc: 0.5212 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 8/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0375 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 9/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1100 - acc: 0.4960 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 10/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9973 - acc: 0.5020 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 11/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9792 - acc: 0.5040 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 12/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1885 - acc: 0.4909 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 13/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0199 - acc: 0.5020 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 14/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0003 - acc: 0.5020 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 15/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1399 - acc: 0.4950 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 16/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0430 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 17/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0837 - acc: 0.4980 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 18/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0693 - acc: 0.4970 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 19/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9756 - acc: 0.5040 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 20/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1399 - acc: 0.4929 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 21/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1487 - acc: 0.4929 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 22/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9776 - acc: 0.5040 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 23/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.8780 - acc: 0.5101 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 24/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1381 - acc: 0.4929 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 25/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9907 - acc: 0.5030 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 26/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0815 - acc: 0.4950 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 27/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1455 - acc: 0.4909 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 28/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.8584 - acc: 0.5121 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 29/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9491 - acc: 0.5010 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 30/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.6639 - acc: 0.5232 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 31/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0576 - acc: 0.4980 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 32/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9357 - acc: 0.5060 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 33/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0227 - acc: 0.5010 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 34/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0410 - acc: 0.4990 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 35/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1058 - acc: 0.4960 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 36/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.8951 - acc: 0.5091 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 37/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.1056 - acc: 0.4970 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 38/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9940 - acc: 0.5040 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 39/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0396 - acc: 0.5010 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 40/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.8626 - acc: 0.5111 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 41/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0884 - acc: 0.4980 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 42/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0417 - acc: 0.5010 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 43/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0576 - acc: 0.4980 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 44/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0565 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 45/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0253 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 46/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.8951 - acc: 0.5091 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 47/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0889 - acc: 0.4980 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 48/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0252 - acc: 0.5010 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 49/50
# 992/992 [==============================] - 4s 4ms/step - loss: 7.9926 - acc: 0.5030 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 50/50
# 992/992 [==============================] - 4s 4ms/step - loss: 8.0410 - acc: 0.5000 - val_loss: 8.0590 - val_acc: 0.5000
# -------------------------------------------------------------------
# ------------------ Evalute the train set ------------------------
# -------------------------------------------------------------------
# Train loss: 8.059047747361713
# Train accuracy: 0.5
#  y_pred_train shape (992,)
# accuracy_score_train with normalize=True:  0.5
# accuracy_score_train with normalize=False :  496
#              precision    recall  f1-score   support
#
#     class 0       1.00      0.50      0.67       992
#     class 1       0.00      0.00      0.00         0
#
# avg / total       1.00      0.50      0.67       992
#
# confusion_matrix :
#  [[496 496]
#  [  0   0]]
# Accuracy :  0.5
# Sensitivity :  1.0
# Specificity :  0.0
# -------------------------------------------------------------------
# ------------------ Evalute the validation set ------------------------
# -------------------------------------------------------------------
# validation loss: 8.059047744257635
# validation accuracy: 0.5
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#  y_pred_train shape (424,)
# accuracy_score_validation with normalize=True:  0.5
# accuracy_score_validation with normalize=False :  212
#              precision    recall  f1-score   support
#
#     class 0       1.00      0.50      0.67       424
#     class 1       0.00      0.00      0.00         0
#
# avg / total       1.00      0.50      0.67       424
#
# confusion_matrix :
#  [[212 212]
#  [  0   0]]
# Accuracy :  0.5
# Sensitivity :  1.0
# Specificity :  0.0
# -------------------------------------------------------------------
# ------------------ Train Done -------------------------------------
# -------------------------------------------------------------------
